# %% [markdown]
# ## Realização de Consulta SPARQL utilizando a API Pública do Wikidata
#
# Este notebook contém um exemplo de consulta SPARQL utilizando a API pública da plataforma Wikidata disponível [neste link](https://query.wikidata.org/), incluindo:
# - **Exemplo de consulta SPARQL** das 100 maiores cidades do mundo por população
# - **Conversão para DataFrame** (pandas)
# - **Visualização dos dados**
#
# > O repositório GitHub com o material da aula pode ser acessado [neste link](https://github.com/BernardoCaixeta/Ontologia-SPARQL)
#
# > Execute as células na ordem. Se estiver em um ambiente novo, execute primeiro a **instalação** das dependências.

# %%
import sys, warnings
import pandas as pd
from SPARQLWrapper import SPARQLWrapper, JSON
import matplotlib.pyplot as plt
import numpy as np
import cartopy.crs as ccrs
import cartopy.feature as cfeature

warnings.simplefilter('ignore', UserWarning)
plt.rcParams['font.sans-serif'] = ['Microsoft YaHei']

# %% [markdown]
# ### URL do endpoint SPARQL público do Wikidata

# %%
endpoint_url = "https://query.wikidata.org/sparql"

# %% [markdown]
# ### Consulta SPARQL
# > - `?city wdt:P31/wdt:P279* wd:Q515`    → instância (P31) de algo que é (via cadeia de "subclasse de" P279*) 'cidade' (Q515)
# > - `?city wdt:P1082 ?population`        → população
# > - `?city wdt:P625  ?gps`               → coordenadas (WKT: Point(lon lat))
# > - Subconsulta (%i) ordena por população desc e limita em 100; o INCLUDE %i reaproveita o conjunto filtrado.
# > - `SERVICE wikibase:label` adiciona rótulos legíveis no idioma do usuário.

# %%
query = """#Largest cities of the world
#defaultView:BubbleChart
SELECT ?cityLabel ?population ?gps
WITH {
  SELECT DISTINCT *
  WHERE {
    # ?city wdt:P31/wdt:P279* wd:Q515 .
    # ?city wdt:P1082 ?population .
    # ?city wdt:P625 ?gps .
  }
  ORDER BY DESC(?population)
  LIMIT 100
} AS %i
WHERE {
  INCLUDE %i
  SERVICE wikibase:label { bd:serviceParam wikibase:language "[AUTO_LANGUAGE],mul,en" . }
}
ORDER BY DESC(?population)"""

# %% [markdown]
# ### Função de Consulta
# > - Instancia o cliente SPARQL apontando para o endpoint com o User-Agent informado
# > - Define a consulta SPARQL
# > - Pede o resultado em JSON (também pode ser XML, CSV, Turtle, etc.)
# > - Executa a consulta e converte a resposta para um dicionário Python

# %%
def get_results(endpoint_url, query):
    user_agent = "WDQS-example Python/%s.%s" % (sys.version_info[0], sys.version_info[1])
    sparql = SPARQLWrapper(endpoint_url, agent=user_agent)
    sparql.setQuery(query)
    sparql.setReturnFormat(JSON)
    return sparql.query().convert()

# %% [markdown]
# - Realiza a consulta à API utilizando a query fornecida

# %%
results = get_results(endpoint_url, query)

# %% [markdown]
# - Percorre os bindings (linhas) e imprime cada registro bruto

# %%
for result in results["results"]["bindings"]:
    print(result)
# Out:
# {'population': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '32054159'}, 'gps': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral', 'type': 'literal', 'value': 'Point(106.506944444 29.55)'}, 'cityLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Chongqing'}}
# {'population': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '26495000'}, 'gps': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral', 'type': 'literal', 'value': 'Point(77.216666666 28.666666666)'}, 'cityLabel': {'xml:lang': 'mul', 'type': 'literal', 'value': 'Delhi'}}
# {'population': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '24870895'}, 'gps': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral', 'type': 'literal', 'value': 'Point(121.469166666 31.232222222)'}, 'cityLabel': {'xml:lang': 'mul', 'type': 'literal', 'value': '上海'}}
# {'population': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '21905000'}, 'gps': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral', 'type': 'literal', 'value': 'Point(-99.133158333 19.432519444)'}, 'cityLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Greater Mexico City'}}
# {'population': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '21893095'}, 'gps': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral', 'type': 'literal', 'value': 'Point(116.407526 39.90403)'}, 'cityLabel': {'xml:lang': 'mul', 'type': 'literal', 'value': '北京市'}}
# {'population': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '20937757'}, 'gps': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral', 'type': 'literal', 'value': 'Point(104.063333333 30.66)'}, 'cityLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Chengdu'}}
# {'population': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '19940274'}, 'gps': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral', 'type': 'literal', 'value': 'Point(-74.020277777 40.808611111)'}, 'cityLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'New York metropolitan area'}}
# {'population': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '18676605'}, 'gps': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral', 'type': 'literal', 'value': 'Point(113.26 23.13)'}, 'cityLabel': {'xml:lang': 'mul', 'type': 'literal', 'value': '广州'}}
# {'population': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '17494398'}, 'gps': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral', 'type': 'literal', 'value': 'Point(114.054444444 22.546666666)'}, 'cityLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Shenzhen'}}
# {'population': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '16800000'}, 'gps': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral', 'type': 'literal', 'value': 'Point(90.394444444 23.728888888)'}, 'cityLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Dhaka'}}
# {'population': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '15655924'}, 'gps': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral', 'type': 'literal', 'value': 'Point(28.960277777 41.01)'}, 'cityLabel': {'xml:lang': 'mul', 'type': 'literal', 'value': 'İstanbul'}}
# {'population': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '15414288'}, 'gps': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral', 'type': 'literal', 'value': 'Point(72.8775 19.075833333)'}, 'cityLabel': {'xml:lang': 'mul', 'type': 'literal', 'value': 'Mumbai'}}
# {'population': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '15070000'}, 'gps': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral', 'type': 'literal', 'value': 'Point(3.393611111 6.456111111)'}, 'cityLabel': {'xml:lang': 'mul', 'type': 'literal', 'value': 'Lagos'}}
# {'population': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '14910352'}, 'gps': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral', 'type': 'literal', 'value': 'Point(67.01 24.86)'}, 'cityLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Karachi'}}
# {'population': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '14565700'}, 'gps': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral', 'type': 'literal', 'value': 'Point(15.311944444 -4.321944444)'}, 'cityLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Kinshasa'}}
# {'population': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '14264798'}, 'gps': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral', 'type': 'literal', 'value': 'Point(139.691666666 35.689444444)'}, 'cityLabel': {'xml:lang': 'mul', 'type': 'literal', 'value': '東京都'}}
# {'population': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '14002598'}, 'gps': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral', 'type': 'literal', 'value': 'Point(106.701944444 10.775555555)'}, 'cityLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Ho Chi Minh City'}}
# {'population': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '14001751'}, 'gps': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral', 'type': 'literal', 'value': 'Point(121.0 14.583333333)'}, 'cityLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Metro Manila'}}
# {'population': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '13985794'}, 'gps': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral', 'type': 'literal', 'value': 'Point(-58.3719 -34.6083)'}, 'cityLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Greater Buenos Aires'}}
# {'population': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '13866009'}, 'gps': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral', 'type': 'literal', 'value': 'Point(117.205555555 39.146666666)'}, 'cityLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Tianjin'}}
# {'population': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '13274285'}, 'gps': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral', 'type': 'literal', 'value': 'Point(37.6175 55.750555555)'}, 'cityLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Moscow'}}
# {'population': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '12952907'}, 'gps': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral', 'type': 'literal', 'value': 'Point(108.942222222 34.261111111)'}, 'cityLabel': {'xml:lang': 'en', 'type': 'literal', 'value': "Xi'an"}}
# {'population': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '12748262'}, 'gps': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral', 'type': 'literal', 'value': 'Point(120.619444444 31.3)'}, 'cityLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Suzhou'}}
# {'population': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '12600574'}, 'gps': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral', 'type': 'literal', 'value': 'Point(113.66051 34.74919)'}, 'cityLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Zhengzhou'}}
# {'population': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '12327000'}, 'gps': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral', 'type': 'literal', 'value': 'Point(77.5912997 12.9791198)'}, 'cityLabel': {'xml:lang': 'mul', 'type': 'literal', 'value': 'Beṅgaḷūru'}}
# {'population': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '12326518'}, 'gps': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral', 'type': 'literal', 'value': 'Point(114.2975 30.595)'}, 'cityLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Wuhan'}}
# {'population': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '11936010'}, 'gps': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral', 'type': 'literal', 'value': 'Point(120.1675 30.25)'}, 'cityLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Hangzhou'}}
# {'population': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '11900000'}, 'gps': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral', 'type': 'literal', 'value': 'Point(-43.2078 -22.9028)'}, 'cityLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Greater Rio de Janeiro'}}
# {'population': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '11544036'}, 'gps': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral', 'type': 'literal', 'value': 'Point(115.48452 38.86712)'}, 'cityLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Baoding'}}
# {'population': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '11451999'}, 'gps': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral', 'type': 'literal', 'value': 'Point(-46.633947222 -23.550394444)'}, 'cityLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'São Paulo'}}
# {'population': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '11135191'}, 'gps': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral', 'type': 'literal', 'value': 'Point(106.826944444 -6.175277777)'}, 'cityLabel': {'xml:lang': 'mul', 'type': 'literal', 'value': 'Jakarta'}}
# {'population': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '11126285'}, 'gps': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral', 'type': 'literal', 'value': 'Point(74.343611111 31.549722222)'}, 'cityLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Lahore'}}
# {'population': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '11018365'}, 'gps': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral', 'type': 'literal', 'value': 'Point(118.35019 35.10408)'}, 'cityLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Linyi'}}
# {'population': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '10640458'}, 'gps': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral', 'type': 'literal', 'value': 'Point(114.51 38.0425)'}, 'cityLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Shijiazhuang'}}
# {'population': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '10466625'}, 'gps': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral', 'type': 'literal', 'value': 'Point(113.74928 23.04749)'}, 'cityLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Dongguan'}}
# {'population': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '10136000'}, 'gps': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral', 'type': 'literal', 'value': 'Point(113.66051 34.74919)'}, 'cityLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Zhengzhou'}}
# {'population': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '10071722'}, 'gps': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral', 'type': 'literal', 'value': 'Point(120.4 36.116666666)'}, 'cityLabel': {'xml:lang': 'mul', 'type': 'literal', 'value': '青岛'}}
# {'population': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '10047914'}, 'gps': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral', 'type': 'literal', 'value': 'Point(112.97087 28.19874)'}, 'cityLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Changsha'}}
# {'population': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '10009854'}, 'gps': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral', 'type': 'literal', 'value': 'Point(126.633333333 45.75)'}, 'cityLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Harbin'}}
# {'population': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '9943800'}, 'gps': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral', 'type': 'literal', 'value': 'Point(-77.0375 -12.06)'}, 'cityLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Lima'}}
# {'population': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '9713112'}, 'gps': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral', 'type': 'literal', 'value': 'Point(112.52921 32.99871)'}, 'cityLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Nanyang'}}
# {'population': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '9668465'}, 'gps': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral', 'type': 'literal', 'value': 'Point(126.99 37.56)'}, 'cityLabel': {'xml:lang': 'mul', 'type': 'literal', 'value': '서울특별시'}}
# {'population': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '9640742'}, 'gps': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral', 'type': 'literal', 'value': 'Point(139.774444 35.683889)'}, 'cityLabel': {'xml:lang': 'mul', 'type': 'literal', 'value': 'Tōkyō'}}
# {'population': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '9606916'}, 'gps': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral', 'type': 'literal', 'value': 'Point(31.235833333 30.044444444)'}, 'cityLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Cairo'}}
# {'population': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '9572903'}, 'gps': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral', 'type': 'literal', 'value': 'Point(120.656075 27.999128)'}, 'cityLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Wenzhou'}}
# {'population': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '9498863'}, 'gps': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral', 'type': 'literal', 'value': 'Point(113.105556 23.029167)'}, 'cityLabel': {'xml:lang': 'mul', 'type': 'literal', 'value': '佛山市'}}
# {'population': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '9413990'}, 'gps': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral', 'type': 'literal', 'value': 'Point(114.48937 36.61161)'}, 'cityLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Handan'}}
# {'population': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '9404283'}, 'gps': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral', 'type': 'literal', 'value': 'Point(121.549166666 29.875)'}, 'cityLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Ningbo'}}
# {'population': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '9386705'}, 'gps': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral', 'type': 'literal', 'value': 'Point(119.1 36.716666666)'}, 'cityLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Weifang'}}
# {'population': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '9369881'}, 'gps': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral', 'type': 'literal', 'value': 'Point(117.28083 31.86389)'}, 'cityLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Hefei'}}
# {'population': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '9314685'}, 'gps': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral', 'type': 'literal', 'value': 'Point(118.778888888 32.060833333)'}, 'cityLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Nanjing'}}
# {'population': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '9305000'}, 'gps': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral', 'type': 'literal', 'value': 'Point(78.474722222 17.361666666)'}, 'cityLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Hyderabad'}}
# {'population': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '9209944'}, 'gps': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral', 'type': 'literal', 'value': 'Point(-99.13589 19.353773)'}, 'cityLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Mexico City'}}
# {'population': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '9202432'}, 'gps': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral', 'type': 'literal', 'value': 'Point(116.983333333 36.666666666)'}, 'cityLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Jinan'}}
# {'population': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '9083790'}, 'gps': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral', 'type': 'literal', 'value': 'Point(117.18587 34.26104)'}, 'cityLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Xuzhou'}}
# {'population': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '9070093'}, 'gps': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral', 'type': 'literal', 'value': 'Point(123.428055555 41.8025)'}, 'cityLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Shenyang'}}
# {'population': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '9066906'}, 'gps': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral', 'type': 'literal', 'value': 'Point(125.2 43.9)'}, 'cityLabel': {'xml:lang': 'mul', 'type': 'literal', 'value': '长春市'}}
# {'population': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '9066906'}, 'gps': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral', 'type': 'literal', 'value': 'Point(125.322777777 43.88)'}, 'cityLabel': {'xml:lang': 'mul', 'type': 'literal', 'value': '长春市'}}
# {'population': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '9026015'}, 'gps': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral', 'type': 'literal', 'value': 'Point(114.6418 33.62502)'}, 'cityLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Zhoukou'}}
# {'population': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '9000280'}, 'gps': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral', 'type': 'literal', 'value': 'Point(101.695277777 3.147777777)'}, 'cityLabel': {'xml:lang': 'mul', 'type': 'literal', 'value': 'Kuala Lumpur'}}
# {'population': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '8970014'}, 'gps': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral', 'type': 'literal', 'value': 'Point(114.933611111 25.829166666)'}, 'cityLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Ganzhou'}}
# {'population': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '8804190'}, 'gps': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral', 'type': 'literal', 'value': 'Point(-74.006111111 40.712777777)'}, 'cityLabel': {'xml:lang': 'mul', 'type': 'literal', 'value': 'New York City'}}
# {'population': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '8799728'}, 'gps': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral', 'type': 'literal', 'value': 'Point(-0.1275 51.507222222)'}, 'cityLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'London'}}
# {'population': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '8795939'}, 'gps': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral', 'type': 'literal', 'value': 'Point(115.433333333 35.233333333)'}, 'cityLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Heze'}}
# {'population': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '8782285'}, 'gps': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral', 'type': 'literal', 'value': 'Point(118.58583 24.91389)'}, 'cityLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Quanzhou'}}
# {'population': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '8741584'}, 'gps': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral', 'type': 'literal', 'value': 'Point(108.31501 22.81918)'}, 'cityLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Nanning'}}
# {'population': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '8693706'}, 'gps': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral', 'type': 'literal', 'value': 'Point(51.389722222 35.688888888)'}, 'cityLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Tehran'}}
# {'population': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '8460088'}, 'gps': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral', 'type': 'literal', 'value': 'Point(102.706111111 25.043333333)'}, 'cityLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Kunming'}}
# {'population': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '8435650'}, 'gps': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral', 'type': 'literal', 'value': 'Point(105.84117 21.0245)'}, 'cityLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Hanoi'}}
# {'population': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '8357897'}, 'gps': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral', 'type': 'literal', 'value': 'Point(116.566666666 35.4)'}, 'cityLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Jining'}}
# {'population': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '8291268'}, 'gps': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral', 'type': 'literal', 'value': 'Point(119.291666666 26.076944444)'}, 'cityLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Fuzhou'}}
# {'population': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '8287693'}, 'gps': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral', 'type': 'literal', 'value': 'Point(115.433333333 35.233333333)'}, 'cityLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Heze'}}
# {'population': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '8200264'}, 'gps': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral', 'type': 'literal', 'value': 'Point(115.80447 32.89856)'}, 'cityLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Fuyang'}}
# {'population': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '8126755'}, 'gps': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral', 'type': 'literal', 'value': 'Point(44.366111111 33.315277777)'}, 'cityLabel': {'xml:lang': 'mul', 'type': 'literal', 'value': 'Baghdad'}}
# {'population': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '8034649'}, 'gps': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral', 'type': 'literal', 'value': 'Point(-74.08175 4.60971)'}, 'cityLabel': {'xml:lang': 'mul', 'type': 'literal', 'value': 'Bogotá'}}
# {'population': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '7816831'}, 'gps': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral', 'type': 'literal', 'value': 'Point(115.64673 34.42592)'}, 'cityLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Shangqiu'}}
# {'population': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '7726635'}, 'gps': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral', 'type': 'literal', 'value': 'Point(120.8873 31.98288)'}, 'cityLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Nantong'}}
# {'population': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '7717983'}, 'gps': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral', 'type': 'literal', 'value': 'Point(118.173888888 39.629444444)'}, 'cityLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Tangshan'}}
# {'population': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '7645000'}, 'gps': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral', 'type': 'literal', 'value': 'Point(72.579722222 23.021944444)'}, 'cityLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Ahmedabad'}}
# {'population': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '7639000'}, 'gps': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral', 'type': 'literal', 'value': 'Point(121.549166666 29.875)'}, 'cityLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Ningbo'}}
# {'population': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '7462135'}, 'gps': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral', 'type': 'literal', 'value': 'Point(120.283333 31.566667)'}, 'cityLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Wuxi'}}
# {'population': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '7450785'}, 'gps': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral', 'type': 'literal', 'value': 'Point(121.6 38.9)'}, 'cityLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Dalian'}}
# {'population': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '7413070'}, 'gps': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral', 'type': 'literal', 'value': 'Point(114.158611111 22.278333333)'}, 'cityLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Hong Kong'}}
# {'population': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '7300783'}, 'gps': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral', 'type': 'literal', 'value': 'Point(116.84519 38.30369)'}, 'cityLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Cangzhou'}}
# {'population': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '7111106'}, 'gps': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral', 'type': 'literal', 'value': 'Point(114.47531 37.06594)'}, 'cityLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Xingtai'}}
# {'population': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '7102116'}, 'gps': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral', 'type': 'literal', 'value': 'Point(121.447777777 37.464444444)'}, 'cityLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Yantai'}}
# {'population': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '7056699'}, 'gps': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral', 'type': 'literal', 'value': 'Point(112.453611111 34.683611111)'}, 'cityLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Luoyang'}}
# {'population': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '7056699'}, 'gps': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral', 'type': 'literal', 'value': 'Point(112.42447 34.65867)'}, 'cityLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Luoyang'}}
# {'population': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '7050683'}, 'gps': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral', 'type': 'literal', 'value': 'Point(119.64937 29.10462)'}, 'cityLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Jinhua'}}
# {'population': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '7009100'}, 'gps': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral', 'type': 'literal', 'value': 'Point(46.71 24.65)'}, 'cityLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Riyadh'}}
# {'population': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '7008427'}, 'gps': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral', 'type': 'literal', 'value': 'Point(114.02528 32.97729)'}, 'cityLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Zhumadian'}}
# {'population': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '6981236'}, 'gps': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral', 'type': 'literal', 'value': 'Point(110.403056 21.196667)'}, 'cityLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Zhanjiang'}}
# {'population': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '6899636'}, 'gps': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral', 'type': 'literal', 'value': 'Point(105.28627 27.30193)'}, 'cityLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Bijie'}}
# {'population': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '6874000'}, 'gps': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral', 'type': 'literal', 'value': 'Point(96.15611 16.80528)'}, 'cityLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Yangon'}}
# {'population': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '6874000'}, 'gps': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral', 'type': 'literal', 'value': 'Point(96.16 16.795)'}, 'cityLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Yangon'}}
# {'population': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '6709629'}, 'gps': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral', 'type': 'literal', 'value': 'Point(120.156944444 33.35)'}, 'cityLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Yancheng'}}
# {'population': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '6645243'}, 'gps': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral', 'type': 'literal', 'value': 'Point(112.58568 26.89676)'}, 'cityLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Hengyang'}}
# {'population': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '6622888'}, 'gps': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral', 'type': 'literal', 'value': 'Point(121.42213 28.6583)'}, 'cityLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Taizhou'}}
# {'population': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '6606675'}, 'gps': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral', 'type': 'literal', 'value': 'Point(106.93363 27.70498)'}, 'cityLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Zunyi'}}
# {'population': {'datatype': 'http://www.w3.org/2001/XMLSchema#decimal', 'type': 'literal', 'value': '6599000'}, 'gps': {'datatype': 'http://www.opengis.net/ont/geosparql#wktLiteral', 'type': 'literal', 'value': 'Point(80.275 13.0825)'}, 'cityLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Chennai'}}

# %% [markdown]
# ### Conversão para Tabela (DataFrame do Pandas)

# %%
def bindings_to_dataframe(results):
    rows = []
    for b in results["results"]["bindings"]:
        city = b["cityLabel"]["value"]
        population = int(b["population"]["value"])
        wkt = b["gps"]["value"][6:-1]
        lon, lat = wkt.split(" ")
        rows.append({"Cidade": city, "População": population, "Latitude": lat, "Longitude": lon})
    df = pd.DataFrame(rows).sort_values("População", ascending=False, ignore_index=True)
    return df

# %%
df = bindings_to_dataframe(results)

# %% [markdown]
# - Visualização do DataFrame

# %%
df
# Out:
#                  Cidade  População      Latitude      Longitude
# 0             Chongqing   32054159         29.55  106.506944444
# 1                 Delhi   26495000  28.666666666   77.216666666
# 2                    上海   24870895  31.232222222  121.469166666
# 3   Greater Mexico City   21905000  19.432519444  -99.133158333
# 4                   北京市   21893095      39.90403     116.407526
# ..                  ...        ...           ...            ...
# 95             Yancheng    6709629         33.35  120.156944444
# 96             Hengyang    6645243      26.89676      112.58568
# 97              Taizhou    6622888       28.6583      121.42213
# 98                Zunyi    6606675      27.70498      106.93363
# 99              Chennai    6599000       13.0825         80.275
#
# [100 rows x 4 columns]

# %% [markdown]
# ### Visualizações

# %% [markdown]
# #### **Exemplo 1:** Gráfico de Top 20 cidades por população

# %%
top = df.nlargest(20, "População").iloc[::-1]
plt.figure(figsize=(9, 10))
plt.barh(top["Cidade"], top["População"])
plt.xlabel("População")
plt.ylabel("Cidade")
plt.title("Top 20 cidades por população (Wikidata)")
plt.show()

# %% [markdown]
# #### **Exemplo 2:** Mapa das maiores cidades por população

# %%
df_ = df.dropna(subset=["Latitude", "Longitude", "População"]).copy()

pop = df_["População"].astype(float).to_numpy()
lon = df_["Longitude"].astype(float).to_numpy()
lat = df_["Latitude"].astype(float).to_numpy()

logp = np.log10(np.clip(pop, 1, None))
lo, hi = logp.min(), logp.max()

if hi > lo:
    sizes = np.interp(logp, (lo, hi), (50.0, 1200.0))
else:
    sizes = np.full_like(logp, 300.0)

mask = np.isfinite(lon) & np.isfinite(lat) & np.isfinite(sizes)
lon, lat, sizes = lon[mask], lat[mask], sizes[mask]

fig = plt.figure(figsize=(12, 6))
ax = plt.axes(projection=ccrs.Robinson())
ax.set_global()
ax.coastlines()
ax.add_feature(cfeature.BORDERS, linewidth=0.3)
ax.gridlines(draw_labels=False, linewidth=0.3)

ax.scatter(lon, lat, s=sizes, alpha=0.6, linewidths=0, transform=ccrs.PlateCarree())

if hi > lo:
    for p, label in [(1e6, "1M"), (5e6, "5M"), (2e7, "20M")]:
        lsize = np.interp(np.log10(p), (lo, hi), (50.0, 1200.0))
        ax.scatter([], [], s=lsize, alpha=0.6, linewidths=0, label=label)
    ax.legend(scatterpoints=1, frameon=True, labelspacing=1, title="População", loc="lower left")

plt.title("Conjunto de maiores cidades por população (Wikidata)")
plt.tight_layout()
plt.savefig("2.2 - mapa_cidades_populacao.png")
plt.show()
